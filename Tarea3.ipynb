# %% [markdown]
# <a href="https://colab.research.google.com/github/NetzaiHernandez/daa_2021_1/blob/master/Tarea3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tarea
# 1. En un documento Excel buscar el valor de "n" de la función 1+(n+2n²) y ver el costo que tiene
#
# 2. ¿Que modificación se le podría hacer a la función para que el resultado sea menos costoso?
#
# 3. En el excel debe mostrarse 2 tablas comparativas, la de el costo de la función vista en clase y la función modifica.
#
# Entregar en  un zip
#
# NOTA: pueden usar el lenguaje que prefieran, pero recuerden que no solo es enviar el txt. sino el programa completo.
#
# ![Calculos.jpeg](data:image/jpeg;base64,...)
#
# Se modifico el Codigo quitando la varible suma_reglon y la accion que hacia dentro del segundo for porque no se hacia uso de la misma y es proceso no necesario
#
# Reduciendo nuestra ecuacion a
#
# 1+(n+n^2)

# %%
a2n = [[1, 2, 3, 4], [5, 6, 7,8]]
total = 0
for r in range(len(a2n)):
    for c in range(len(a2n[r])):
        total += a2n[r][c]
print(total)
# Out:
# 36
